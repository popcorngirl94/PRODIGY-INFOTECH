# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\acer\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
population_df = pd.read_csv('Population.csv', skiprows=2, header=2)
population_df.head()
# Out:
#                   Country Name Country Code         1960         1961  \
# 0                        Aruba          ABW      54608.0      55811.0
# 1  Africa Eastern and Southern          AFE  130692579.0  134169237.0
# 2                  Afghanistan          AFG    8622466.0    8790140.0
# 3   Africa Western and Central          AFW   97256290.0   99314028.0
# 4                       Angola          AGO    5357195.0    5441333.0
#
#           1962         1963         1964         1965         1966  \
# 0      56682.0      57475.0      58178.0      58782.0      59291.0
# 1  137835590.0  141630546.0  145605995.0  149742351.0  153955516.0
# 2    8969047.0    9157465.0    9355514.0    9565147.0    9783147.0
# 3  101445032.0  103667517.0  105959979.0  108336203.0  110798486.0
# 4    5521400.0    5599827.0    5673199.0    5736582.0    5787044.0
#
#           1967  ...         2013         2014         2015         2016  \
# ...

# %%
population_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  266 non-null    object
#  1   Country Code  266 non-null    object
#  2   1960          264 non-null    float64
#  3   1961          264 non-null    float64
#  4   1962          264 non-null    float64
#  5   1963          264 non-null    float64
#  6   1964          264 non-null    float64
#  7   1965          264 non-null    float64
#  8   1966          264 non-null    float64
#  9   1967          264 non-null    float64
#  10  1968          264 non-null    float64
#  11  1969          264 non-null    float64
#  12  1970          264 non-null    float64
#  13  1971          264 non-null    float64
#  14  1972          264 non-null    float64
#  15  1973          264 non-null    float64
#  16  1974          264 non-null    float64
# ...

# %%
population_df.isna().sum()
# Out:
# Country Name    0
# Country Code    0
# 1960            2
# 1961            2
# 1962            2
#                ..
# 2018            1
# 2019            1
# 2020            1
# 2021            1
# 2022            1
# Length: 65, dtype: int64

# %%
population_df = population_df.dropna()

# %%
population_df.isna().sum()
# Out:
# Country Name    0
# Country Code    0
# 1960            0
# 1961            0
# 1962            0
#                ..
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# 2022            0
# Length: 65, dtype: int64

# %%
population_df.duplicated().sum()
# Out:
# 0

# %%
print(population_df.dtypes)
# Out:
# Country Name     object
# Country Code     object
# 1960            float64
# 1961            float64
# 1962            float64
#                  ...
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# 2022            float64
# Length: 65, dtype: object

# %%
sns.displot(data=population_df, x='2021', kind='hist',aspect=2, height = 8)
plt.title('Distribution of Population in Year 2021')
plt.xlabel('Year 2021')
plt.ylabel('Count')
plt.show()

# %%
sns.catplot(data=population_df, x='Country Name',y='2021',aspect=4, height=10, kind='bar')
plt.title('Country wise Population in 2021')
plt.xlabel('Country')
plt.ylabel('Year-2021')
plt.xticks(rotation=90)
plt.show()

# %%
sns.set_style("whitegrid")

population_column = '2021'
plt.figure(figsize=(10, 6))
sns.histplot(data=population_df, x=population_column, bins=20, color='skyblue', edgecolor='black', kde=True)
plt.title('Distribution of Population in Year 2021', fontsize=16)
plt.xlabel('Population', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True)
plt.show()

# %%
sns.set_style("whitegrid")

population_column = '2021'
plt.figure(figsize=(15, 8))
sns.barplot(data=population_df, x='Country Name', y=population_column, color='skyblue')
plt.title('Country-wise Population in 2021', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel(f'Population in {population_column}', fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=12)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()  
plt.show()
